# %%
# Web Scrapping

# %%
#Send a request to a website and extract the top 5 headlines

# %%
pip install requests beautifulsoup4 pandas

# %%
import requests
from bs4 import BeautifulSoup

url = "https://news.ycombinator.com/"

response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

headlines = soup.find_all("span", class_="titleline")

print("Top 5 Headlines:\n")

for i, headline in enumerate(headlines[:5], start=1):
    print(i, headline.get_text())
# Out:
# Top 5 Headlines:
#
# 1 libexpat now funded by the City of Munich for up to 6 months (hartwork.org)
# 2 After Losses, Retail Investors Flock to 3x Leverage as 2x Product Are Restricted (asiae.co.kr)
# 3 Pi's Minimalism Is Its Advantage (earendil.com)
# 4 Eight Myths on Software Engineering and GenAI (acm.org)
# 5 Mistral's Shieldstral: 3B open-weights model for multimodal moderation (mistral.ai)

# %%
#2 Extract all hyperlinks (text and URL) using <a> tags

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.python.org/"

response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

links = soup.find_all("a")

for link in links:
    text = link.get_text(strip=True)
    href = link.get("href")

    print("Text :", text)
    print("URL  :", href)
    print("-" * 40)
# Out:
# Text : Skip to content
# URL  : #content
# ----------------------------------------
# Text : ▼Close
# URL  : #python-network
# ----------------------------------------
# Text : Python
# URL  : /
# ----------------------------------------
# Text : PSF
# URL  : https://www.python.org/psf/
# ----------------------------------------
# Text : Docs
# URL  : https://docs.python.org
# ----------------------------------------
# Text : PyPI
# URL  : https://pypi.org/
# ----------------------------------------
# Text : Jobs
# URL  : /jobs/
# ----------------------------------------
# Text : Community
# URL  : /community/
# ----------------------------------------
# Text : ▲The Python Network
# URL  : #top
# ----------------------------------------
# Text :
# URL  : /
# ----------------------------------------
# Text : Donate
# URL  : https://donate.python.org/
# ----------------------------------------
# Text : ≡Menu
# URL  : #site-map
# ----------------------------------------
# Text : AA
# ...

# %%
#3 Scrape and display titles of first 10 items

# %%
import requests
from bs4 import BeautifulSoup

url = "https://news.ycombinator.com/"

response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

titles = soup.find_all("span", class_="titleline")

print("First 10 Titles:\n")

for title in titles[:10]:
    print(title.get_text())
# Out:
# First 10 Titles:
#
# libexpat now funded by the City of Munich for up to 6 months (hartwork.org)
# After Losses, Retail Investors Flock to 3x Leverage as 2x Product Are Restricted (asiae.co.kr)
# Pi's Minimalism Is Its Advantage (earendil.com)
# Eight Myths on Software Engineering and GenAI (acm.org)
# Mistral's Shieldstral: 3B open-weights model for multimodal moderation (mistral.ai)
# IP and DNS Leaks in WebKit Affecting Proxy Browsers and iCloud Private Relay (mysk.blog)
# Stateless MCP has recaptured my interest (simonwillison.net)
# Zigbee vs. Matter over Thread:Understanding IoT Protocol Performance in Practice (arxiv.org)
# Show HN: Simple algorithm and color space to generate diverse skin tones (toneyalexander.github.io)
# DuckDB – Data power tools for your laptop, now in Clojure (2023) (techascent.com)

# %%
#4 Extract text data along with related information (title and URL)

# %%
import requests
from bs4 import BeautifulSoup

url = "https://news.ycombinator.com/"

response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

items = soup.find_all("span", class_="titleline")

for item in items[:10]:
    link = item.find("a")

    title = link.get_text()
    url = link.get("href")

    print("Title :", title)
    print("Link  :", url)
    print("-" * 50)
# Out:
# Title : libexpat now funded by the City of Munich for up to 6 months
# Link  : https://blog.hartwork.org/posts/libexpat-city-of-munich-open-source-sabbatical/
# --------------------------------------------------
# Title : After Losses, Retail Investors Flock to 3x Leverage as 2x Product Are Restricted
# Link  : https://www.asiae.co.kr/en/article/2026080416131786841
# --------------------------------------------------
# Title : Pi's Minimalism Is Its Advantage
# Link  : https://earendil.com/posts/pi-autoresearch-and-databricks/
# --------------------------------------------------
# Title : Eight Myths on Software Engineering and GenAI
# Link  : https://queue.acm.org/detail.cfm?id=3807963
# --------------------------------------------------
# Title : Mistral's Shieldstral: 3B open-weights model for multimodal moderation
# Link  : https://mistral.ai/news/shieldstral/
# --------------------------------------------------
# ...

# %%
#5 Scrape top items using User-Agent header

# %%
import requests
from bs4 import BeautifulSoup

url = "https://news.ycombinator.com/"

headers = {
    "User-Agent": "Mozilla/5.0"
}

response = requests.get(url, headers=headers)

soup = BeautifulSoup(response.text, "html.parser")

titles = soup.find_all("span", class_="titleline")

print("Top 5 Items:\n")

for title in titles[:5]:
    print(title.get_text())
# Out:
# Top 5 Items:
#
# libexpat now funded by the City of Munich for up to 6 months (hartwork.org)
# After Losses, Retail Investors Flock to 3x Leverage as 2x Product Are Restricted (asiae.co.kr)
# Pi's Minimalism Is Its Advantage (earendil.com)
# Eight Myths on Software Engineering and GenAI (acm.org)
# Mistral's Shieldstral: 3B open-weights model for multimodal moderation (mistral.ai)

# %%
#6 Extract data from an HTML table

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.w3schools.com/html/html_tables.asp"

response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

table = soup.find("table")

rows = table.find_all("tr")

for row in rows:
    cols = row.find_all(["th", "td"])

    data = [col.get_text(strip=True) for col in cols]

    print(data)
# Out:
# ['Company', 'Contact', 'Country']
# ['Alfreds Futterkiste', 'Maria Anders', 'Germany']
# ['Centro comercial Moctezuma', 'Francisco Chang', 'Mexico']
# ['Ernst Handel', 'Roland Mendel', 'Austria']
# ['Island Trading', 'Helen Bennett', 'UK']
# ['Laughing Bacchus Winecellars', 'Yoshi Tannamuri', 'Canada']
# ['Magazzini Alimentari Riuniti', 'Giovanni Rovelli', 'Italy']

# %%
#7 Scrape a table and convert it into a Pandas DataFrame

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://www.w3schools.com/html/html_tables.asp"

response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

table = soup.find("table")

rows = table.find_all("tr")

data = []

for row in rows:
    cols = row.find_all(["th", "td"])
    cols = [col.get_text(strip=True) for col in cols]
    data.append(cols)

headers = data[0]
table_data = data[1:]

df = pd.DataFrame(table_data, columns=headers)

print(df)
# Out:
#                         Company           Contact  Country
# 0           Alfreds Futterkiste      Maria Anders  Germany
# 1    Centro comercial Moctezuma   Francisco Chang   Mexico
# 2                  Ernst Handel     Roland Mendel  Austria
# 3                Island Trading     Helen Bennett       UK
# 4  Laughing Bacchus Winecellars   Yoshi Tannamuri   Canada
# 5  Magazzini Alimentari Riuniti  Giovanni Rovelli    Italy
